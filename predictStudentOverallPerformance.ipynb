# %%
import matplotlib.pyplot as plot
import seaborn as sns
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score, f1_score, recall_score, precision_score

# %%
df = pd.read_csv("../input/clean-data/final_data.csv")
df.dropna(inplace=True)
df
df.shape

# %%
df.describe()

# %%
df.info()

# %%
df.head()

# %%
c=df.columns
df[c].hist(bins=50, figsize=(21,16))

# %%
f = plot.figure(figsize=(15, 15))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(df.corr(),cmap='YlOrBr')

# %%
sns.histplot(x='Unemployment rate',data=df,hue='Target')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
df_new=df.drop('Target',axis=1)
X_training, X_testing, y_training, y_testing = train_test_split(df_new, df['Target'], test_size=0.2, random_state=103)

# %%
from sklearn.linear_model import LogisticRegression
logregression = LogisticRegression(max_iter=10000)
logregression.fit(X_training,y_training)
LogisticRegression(max_iter=10000)
predictions = logregression.predict(X_testing)

# %%
from sklearn.linear_model import LogisticRegression
logregression = LogisticRegression(max_iter=1000)
logregression.fit(X_training,y_training)
predictions = logregression.predict(X_test)

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(logregression, X_testing, y_testing, cmap="Greys")
plot.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_training,y_training)
KNeighborsClassifier(n_neighbors=1)
predictions = knn.predict(X_testing)

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(knn, X_testing, y_testing, cmap="Greys")
plot.show()

# %%
error_rate = []

for i in range(1,20):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_training,y_training)
    pred_i = knn.predict(X_testing)
    error_rate.append(np.mean(pred_i != y_testing))

# %%
knn = KNeighborsClassifier(n_neighbors=11)
knn.fit(X_training,y_training)
predictions = knn.predict(X_testing)

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(knn, X_testing, y_testing, cmap="Greys")
plot.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf.fit(X_training,y_training)
RandomForestClassifier(n_estimators=200)
predictions = rf.predict(X_testing)

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(rf, X_testing, y_testing, cmap="Greys")
plot.show()

# %%
from sklearn.svm import SVC
model = SVC()
from sklearn.model_selection import GridSearchCV
param_grid = {'C':[0.1,1,10,100,1000],'gamma':[1,0.1,0.01,0.001,0.0001]}
grid = GridSearchCV(SVC(),param_grid,verbose=3)
grid.fit(X_training,y_training)
